# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
#1
C = int(input("Введите градусы в Цельсиях: "))
F = (C * (9/5) + 32)
print(f"Фаренгейты: {F}")
# Out:
# Фаренгейты: 68.0

# %%
#2
fn = input("Введите Ваше имя: ")
ln = input("Введите Вашу фамилию: ")
print(fn + " " + ln)
# Out:
# Таисия Хвостова

# %%
#3
a, b = int(input("Длина: ")), int(input("Ширина: "))
print("Площадь: ", a * b)
# Out:
# Площадь:  10

# %%
#4
a, b = 10, 3
print(a+b, a-b, a*b, float(a/b), a^b)
# Out:
# 13 7 30 3.3333333333333335 9

# %%
#5
print(len(input("Введите любое слово: ")))
# Out:
# 11

# %%
#6
ans = int(int(input()) % 2 == 0)
ans2 = not ans 
print("Число четное!"*ans, "Число нечетное!"*ans2)
# Out:
#  Число нечетное!

# %%
#7
n = input("Любое слово: ")
print((n+"\n")*int(input()))
# Out:
# aaaaa
# aaaaa
# aaaaa
# aaaaa
# aaaaa

# %%
#8
minutes = int(input("Введите количество минут: "))
print(minutes//60, "ч", minutes%60, "мин")
# Out:
# 2 ч 5 мин

# %%
#9
import math 
a, b, c = int(input("a")), int(input("b")), int(input("c"))
p = a+b+c
print("S =", math.sqrt(p*(p-a)*(p-b)*(p-c)))
# Out:
# S = 77.76888838089432

# %%
#Задачи со строками

# %%
#1
s = input()
print(s[:3:], "\n", s[-3::])
# Out:
# Про
#  ние

# %%
#2
print(input()[::-1])
# Out:
# тевирП

# %%
#3
s1, s2 = input("Строка:"), input("Подстрока:")
ans = int(s2 in s1)
ans2 = not ans
print("Да, подстрока найдена!"*ans, "Подстрока не найдена"*ans2)
# Out:
#  Подстрока не найдена

# %%
#4
s0 = "Я люблю Python, Python — лучший!"
print(s0.replace("Python", "JavaScript"))
# Out:
# Я люблю JavaScript, JavaScript — лучший!

# %%
#5
s00 = "apple,banana,orange,grape"
print(*s00.split(","))
# Out:
# apple banana orange grape

# %%
#6
s6, s61 = input("Строка"), input("Символ")
print(f"Символ '{s61}' встречается {s6.count(s61)} раз")
# Out:
# Символ 'a' встречается 5 раз

# %%
#7
h = " Hello, world! "
h1 = h.replace(" ", "")
print(h1.replace(",", ", "))
# Out:
# Hello, world!

# %%
#8
abc = "abc123def45gh6"
print(abc[3:6:]+abc[9:11:]+abc[-1::])
# Out:
# 123456

# %%
#9
number = "+71234567890"
print(number[:2:]+" ("+number[2:5]+") "+number[5:8]+"-"+number[8:10]+"-"+number[10:])
# Out:
# +7 (123) 456-78-90

# %%
#10 через цикл
l = input()
l1 =  ''
for i in range(len(l)):
    l1 += chr(ord(l[i])+1)
print(l1)
# Out:
# bcd

# %%
#10
#alf = "abcdefghijklmnopqrstuvwxyza"
l = input()
print(l.maketrans(chr(ord(l[i])), chr(ord(l[i])+1)))
# Out:
# {99: 100}
